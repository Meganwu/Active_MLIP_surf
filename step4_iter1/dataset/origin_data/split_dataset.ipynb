# %%
from ase.io import read, write

# %%
mols0=read('/scratch/phys/sin/Nian_Wu/active_both_au_nacl_latest_version/active_MLIP_nacl_au/step4_iter1/dataset/iter0_distort_DFT_50.xyz', index=':')

# %%
train_mols = mols0[:40]
val_mols = mols0[40:45]
test_mols = mols0[45:]

write('train_iter0_distort_DFT_40.xyz', train_mols, format='extxyz')
write('val_iter0_distort_DFT_5.xyz', val_mols, format='extxyz')
write('test_iter0_distort_DFT_5.xyz', test_mols, format='extxyz')

# %%
mols1=read('/scratch/phys/sin/Nian_Wu/active_both_au_nacl_latest_version/active_MLIP_nacl_au/step4_iter1/dataset/iter0_select_DFT_50.xyz', index=':')
train_mols = mols1[:40]
val_mols = mols1[40:45]
test_mols = mols1[45:]

write('train_iter0_select_DFT_40.xyz', train_mols, format='extxyz')
write('val_iter0_select_DFT_5.xyz', val_mols, format='extxyz')
write('test_iter0_select_DFT_5.xyz', test_mols, format='extxyz')

# %%
! cat train_iter0_select_DFT_40.xyz  train_iter0_distort_DFT_40.xyz > train_iter0_both_DFT_80.xyz
! cat val_iter0_select_DFT_5.xyz  val_iter0_distort_DFT_5.xyz > val_iter0_both_DFT_10.xyz
! cat test_iter0_select_DFT_5.xyz  test_iter0_distort_DFT_5.xyz > test_iter0_both_DFT_10.xyz
